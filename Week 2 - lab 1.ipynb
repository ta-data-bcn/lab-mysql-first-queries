# %%
1. Which are the different genres?

SELECT genre
FROM ratings
GROUP BY genre;

Games
Productivity
Weather
Shopping
Reference
Finance
Music
Utilities
Travel
Social Networking
Sports
Business
Health & Fitness
Entertainment
Photo & Video
Navigation
Education
Lifestyle
Food & Drink
News
Book
Medical
Catalogs
Games

2. Which is the genre with more apps rated?

SELECT genre, count(totalratings)
FROM ratings
GROUP BY genre
ORDER BY count(totalratings) desc
LIMIT 1;

Games 	3861

3. Which is the genre with more apps?

SELECT genre, count(appname)
FROM ratings
GROUP BY genre
ORDER BY count(appname) DESC
LIMIT 1;


Games	3861

4. Which is the one with less?

SELECT genre, count(appname)
FROM ratings
GROUP BY genre
ORDER BY count(appname) ASC
LIMIT 2;

Games	1
Catalogs 	10
#he puesto dos porque no pillo por que ese game queda suelto por todo, maybe un error?

5. Take the 10 apps most rated.

SELECT appname, totalratings
FROM ratings
ORDER BY totalratings DESC
LIMIT 10;

White Noise	5
iTranslate - Language Translator & Dictionary	5
Star Walk - Find Stars And Planets in Sky Above	5
Period Tracker Deluxe	5
Bible	5
:) Sudoku +	5
Escape the Sweet Shop Series	5
First Words Animals	5
PCalc - The Best Calculator	5
HotSchedules	5


#o si la database esta mal y, en realidad, las dos columnas de currentversion ratings van sumadas y juntas en una columna:

SELECT appname, currentversionrating+currentversionratings
FROM ratings
ORDER BY currentversionrating+currentversionratings desc
limit 10;


Facebook	2974888
Instagram	2162847
Clash of Clans	2131384
Temple Run	1728388
Pandora - Music & Radio	1130473
Pinterest	1063438
Bible	991240
Candy Crush Saga	964247
Spotify Music	886816
Angry Birds	824558


6. Take the 10 apps best rated by users.

SELECT appname, overallrating
FROM ratings
ORDER BY overallrating DESC
LIMIT 10;

TurboScan™ Pro - document & receipt scanner: scan multiple pages and photos to PDF	5
Flashlight Ⓞ	5
Learn to Speak Spanish Fast With MosaLingua	5
:) Sudoku +	5
The Photographer's Ephemeris	5
King of Dragon Pass	5
Escape the Sweet Shop Series	5
Infinity Blade	5
Plants vs. Zombies HD	5
Plants vs. Zombies	5


7. Take a look on the data you retrieved in the question 5. Give some insights.

#insights opción a
#Price is under 2.99€ in 8 out of 10 apps.
#genres games and health & fitness are the genres most rated


#insights opción b:
#All the apps are free
#games is the genre most rated follow by social networking and music

8. Take a look on the data you retrieved in the question 6. Give some insights.

#Just 2 out of 10 of the apps are free 
#6 out of 10 of the most rated apps are games  

9. Now compare the data from questions 5 and 6. What do you see?

#it seems that people does not mind to pay a little if they really like the app
#games seems to be the favorite genre for apps


10. How could you take the top 3 regarding the user ratings but also the number of votes?

SELECT appname, overallrating, currentversionrating+currentversionratings
FROM ratings
ORDER BY overallrating DESC, currentversionrating+currentversionratings DESC
LIMIT 3;

Infinity Blade	5	503532
Head Soccer	5	490082
Plants vs. Zombies	5	427143

11. Does people care about the price? Do some queries, comment why are you doing them and the results you retrieve. What is your conclusion?
